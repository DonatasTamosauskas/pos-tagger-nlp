# %%
import os
import math
import sys
import torch

def tag_sentence(test_file, model_file, out_file):
    # write your code here. You can add functions as well.
    # use torch library to load model_file
    print('Finished...')

if __name__ == "__main__":
    # make no changes here
#     test_file = sys.argv[1]
#     model_file = sys.argv[2]
#     out_file = sys.argv[3]
#     tag_sentence(test_file, model_file, out_file)
    pass

# %% [markdown]
# # Loading model & dictionary

# %%
def load_model(model_filename):
    model = torch.load(model_filename + "_1.data")
    dictionaries = torch.load(model_filename + "_2.data")
    return model, dictionaries

# %%
import torch.nn as nn
import torch.nn.functional as F

class LSTMTagger(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, tagset_size):
        super(LSTMTagger, self).__init__()
        self.hidden_dim = hidden_dim

        self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)

        # The LSTM takes word embeddings as inputs, and outputs hidden states
        # with dimensionality hidden_dim.
        self.lstm = nn.LSTM(embedding_dim, hidden_dim)

        # The linear layer that maps from hidden state space to tag space
        self.hidden2tag = nn.Linear(hidden_dim, tagset_size)

    def forward(self, sentence):
        embeds = self.word_embeddings(sentence)
        lstm_out, _ = self.lstm(embeds.view(len(sentence[-1]), 1, -1))
        tag_space = self.hidden2tag(lstm_out.view(len(sentence[-1]), -1))
        tag_scores = F.log_softmax(tag_space, dim=1)
        return tag_scores

# %%
import torch
import torch.utils.data


class Dataset(torch.utils.data.Dataset):
    def __init__(self, path, to_lower=True, training=True):
        self.to_lower = to_lower
        self.training = training
        
        self.sentences = []
        self.vocab = []
        self.tags = []
        
        self.generate_dataset(path)
    
    def __len__(self):
        return len(self.sentences)
    
    def __getitem__(self, index):
        sentence_embs, tag_embs = self.transform_sentence(self.sentences[index])
        return sentence_embs, tag_embs
    
    def generate_dataset(self, path):
        with open(path, 'r') as input_file:
            self.sentences = input_file.read().split("\n")
            
            if len(self.vocab) == 0:
                self.create_vocabs(self.sentences)
                self.vocab_size = len(self.vocab)
                self.tag_size = len(self.tags)
            
            if self.sentences[-1] == "":
                self.sentences.pop()
    
    def create_vocabs(self, sentences):
        vocab_set = set()
        tag_set = set()

        for sentence in sentences:
            for word in sentence.split(" "):
                try:
                    word, tag = self.split_words_tag(word)
                    vocab_set.add(word.lower() if self.to_lower else word)
                    tag_set.add(tag)
                except RuntimeError:
                    print("Not a valid word/tag pair: " + word)

        self.vocab = list(vocab_set)
        self.tags = list(tag_set)
            
    def transform_sentence(self, sentence):
        numeric_sent = []
        tags = []

        for word_tag in sentence.split(" "):
            try:
                if self.training:
                    word, tag = self.split_words_tag(word_tag)
                    tag_id = self.tags.index(tag)
                else:
                    word = word_tag
                    
                word_id = self.vocab.index(word.lower() if self.to_lower else word)

            except RuntimeError:
                print("Not a valid word/tag pair: " + word_tag)
            except ValueError:
                print("Word not in the vocab: " + word_tag)
                # The id of an unknown word
                word_id = len(self.vocab) - 1

            numeric_sent.append(word_id)
            if self.training: tags.append(tag_id)

        return torch.tensor(numeric_sent), torch.tensor(tags) if self.training else []

    @staticmethod
    def split_words_tag(word):
        words_tag = word.split("/")
        
        if len(words_tag) < 2: 
            raise RuntimeError("Not a valid word/tag pair:" + word)
            
        tag = words_tag.pop()
        word = "/".join(words_tag)
        
        return word, tag
    
    def print_sentence(self, sentence):
        print(" ".join([self.vocab[word.item()] for word in sentence.view(-1)]))
                
    def decode_sentence(self, sentence):
        return [self.vocab[word.item()] for word in sentence.view(-1)]
    
    def decode_tags(self, tag_ids):
        return [self.tags[tag.item()] for tag in tag_ids.view(-1)]
    
    def __getstate__(self):
        d = dict(self.__dict__)
        del d['sentences']
        return d
    
    def __setstate(self, d):
        self.__dict__.update(d)
        self.__dict__.update({'sentences': []})

# %%
model, dataset = load_model("LSTMTagger_5")

# %% [markdown]
# # Digesting the new input data

# %%
from pathlib import Path

test_data = Path("../data/sents.test")
dataset.generate_dataset(test_data)
dataset.training = False

# %%
# %%time
from torch.utils.data import DataLoader

gpu = torch.device("cuda")
cpu = torch.device("cpu")
model.to(cpu)
dataloader = DataLoader(dataset, batch_size=1, shuffle=False, num_workers=4)

i = 0

preds = []
for x, _ in dataloader:
#     if i > 100:
#         break
#     i += 1
    predictions = model(x.to(cpu))
    _, pos_tag_ids = predictions.max(1)
    
    words = dataset.decode_sentence(x)
    tags = dataset.decode_tags(pos_tag_ids)
    word_tags = ["/".join(word_tag) for word_tag in zip(words, tags)]
    
    preds.append(" ".join(word_tags))
# Out:
# Word not in the vocab: forest-product
# Word not in the vocab: overpaying
# Word not in the vocab: A.D.
# Word not in the vocab: WTD
# Word not in the vocab: Correll
# Word not in the vocab: Polytechnic
# Word not in the vocab: Correll
# Word not in the vocab: Strother
# Word not in the vocab: Pamplin
# Word not in the vocab: researching
# Word not in the vocab: Pamplin
# Word not in the vocab: enticed
# Word not in the vocab: befuddled
# Word not in the vocab: Phi
# Word not in the vocab: Kappa
# Word not in the vocab: retentive
# Word not in the vocab: non-core
# Word not in the vocab: recession-inspired
# Word not in the vocab: 467
# Word not in the vocab: reallocate
# Word not in the vocab: 30,537
# Word not in the vocab: reallocated
# Word not in the vocab: 23,403
# Word not in the vocab: Barbados
# Word not in the vocab: Californian
# Word not in the vocab: upsetting
# Word not in the vocab: Backseat
# Word not in the vocab: railings
# Word not in the vocab: railings
# Word not in the vocab: railing
# Word not in the vocab: railing
# Word not in the vocab: Garret
# Word not in the vocab: four-foot-high
# Word not in the vocab: medallions
# Word not in the vocab: Earlham
# Word not in the vocab: railings
# Word not in the vocab: slab
# Word not in the vocab: relegated
# Word not in the vocab: railing
# Word not in the vocab: railings
# Word not in the vocab: Tray
# Word not in the vocab: PORTING
# Word not in the vocab: Cartons
# Word not in the vocab: POTABLES
# Word not in the vocab: cardboard
# Word not in the vocab: Scypher
# Word not in the vocab: Cup-Tote
# Word not in the vocab: tote
# Word not in the vocab: trays
# Word not in the vocab: loops
# Word not in the vocab: Claire
# Word not in the vocab: spilling
# Word not in the vocab: loops
# Word not in the vocab: Lids
# Word not in the vocab: web
# Word not in the vocab: recyclable
# Word not in the vocab: trays
# Word not in the vocab: blender
# Word not in the vocab: Droz
# Word not in the vocab: Mutchin
# Word not in the vocab: Droz
# Word not in the vocab: corkscrews
# Word not in the vocab: Eggers
# Word not in the vocab: six-inch
# Word not in the vocab: semicircular
# Word not in the vocab: Eggers
# Word not in the vocab: Eggers
# Word not in the vocab: OSHA
# Word not in the vocab: Fairless
# Word not in the vocab: Clairton
# Word not in the vocab: electrical-safety
# Word not in the vocab: crane-safety
# Word not in the vocab: OSHA
# Word not in the vocab: OSHA
# Word not in the vocab: Scannell
# Word not in the vocab: flagrant
# Word not in the vocab: OSHA
# Word not in the vocab: Fairless
# Word not in the vocab: OSHA
# Word not in the vocab: corporate-wide
# Word not in the vocab: OSHA
# Word not in the vocab: Clairton
# Word not in the vocab: bygone
# Word not in the vocab: 1903
# Word not in the vocab: Bellows
# Word not in the vocab: limping
# Word not in the vocab: Danzig
# Word not in the vocab: newsroom
# Word not in the vocab: long-tenured
# Word not in the vocab: newsroom
# Word not in the vocab: crying
# Word not in the vocab: Furillo
# Word not in the vocab: pressman
# Word not in the vocab: headlined
# Word not in the vocab: radio-station
# Word not in the vocab: car-care
# Word not in the vocab: truth-in-lending
# Word not in the vocab: screened
# Word not in the vocab: preapproved
# Word not in the vocab: card-member
# Word not in the vocab: Express-Buick
# Word not in the vocab: travel-related
# Word not in the vocab: Hammersmith
# Word not in the vocab: Fulham
# Word not in the vocab: Hammersmith
# Word not in the vocab: retraced
# Word not in the vocab: Hazell
# Word not in the vocab: Hammersmith
# Word not in the vocab: capital-markets
# Word not in the vocab: Hammersmith
# Word not in the vocab: Fulham
# Word not in the vocab: capital-markets
# Word not in the vocab: Hammersmith
# Word not in the vocab: persuasive
# Word not in the vocab: illegality
# Word not in the vocab: letter-writing
# Word not in the vocab: quashing
# Word not in the vocab: lightning-fast
# Word not in the vocab: ascendency
# Word not in the vocab: wizards
# Word not in the vocab: ramparts
# Word not in the vocab: mobilizing
# Word not in the vocab: clannish
# Word not in the vocab: bludgeon
# Word not in the vocab: tormentors
# Word not in the vocab: gigantic
# Word not in the vocab: Neuberger
# Word not in the vocab: CEOs
# Word not in the vocab: anti-program
# Word not in the vocab: racket
# Word not in the vocab: pitting
# Word not in the vocab: manipulators
# Word not in the vocab: shambles
# Word not in the vocab: Off-Track
# Word not in the vocab: Brean
# Word not in the vocab: Brean
# Word not in the vocab: Neanderthals
# Word not in the vocab: free-enterprise
# Word not in the vocab: boogieman
# Word not in the vocab: beg
# Word not in the vocab: lotter
# Word not in the vocab: profess
# Word not in the vocab: despise
# Word not in the vocab: Zicklin
# Word not in the vocab: iota
# Word not in the vocab: Neuberger
# Word not in the vocab: overleveraged
# Word not in the vocab: jockeys
# Word not in the vocab: benchmarks
# Word not in the vocab: stock-specialist
# Word not in the vocab: knell
# Word not in the vocab: 71,309
# Word not in the vocab: nameless
# Word not in the vocab: Sigler
# Word not in the vocab: sweatshirts
# Word not in the vocab: Sigler
# Word not in the vocab: sparkplugs
# Word not in the vocab: bloods
# Word not in the vocab: lynch-mob
# Word not in the vocab: hunker
# Word not in the vocab: minted
# Word not in the vocab: cow
# Word not in the vocab: gored
# Word not in the vocab: anti-programmers
# Word not in the vocab: genie
# Word not in the vocab: anti-programmers
# Word not in the vocab: middle-ground
# Word not in the vocab: good-faith
# Word not in the vocab: band-wagon
# Word not in the vocab: widget
# Word not in the vocab: widgets
# Word not in the vocab: widget
# Word not in the vocab: widget
# Word not in the vocab: leveraging
# Word not in the vocab: widget
# Word not in the vocab: fundamentalist
# Word not in the vocab: transacting
# Word not in the vocab: hysteria
# Word not in the vocab: desires
# Word not in the vocab: widget
# Word not in the vocab: unneeded
# Word not in the vocab: evoking
# Word not in the vocab: curses
# Word not in the vocab: initiating
# Word not in the vocab: Johnson-era
# Word not in the vocab: Neuberger
# Word not in the vocab: Neuberger
# Word not in the vocab: noncompetitively
# Word not in the vocab: 50/50
# Word not in the vocab: Mariotta
# Word not in the vocab: Neuberger
# Word not in the vocab: blighted
# Word not in the vocab: entrusted
# Word not in the vocab: Neuberger
# Word not in the vocab: ancestry
# Word not in the vocab: Mariotta
# Word not in the vocab: Meese
# Word not in the vocab: Lyn
# Word not in the vocab: Nofzinger
# Word not in the vocab: befell
# Word not in the vocab: easy-to-read
# Word not in the vocab: ingenuity
# Word not in the vocab: Mariotta
# Word not in the vocab: semiliterate
# Word not in the vocab: Lobsenz
# Word not in the vocab: lifes
# Word not in the vocab: tidbits
# Word not in the vocab: auspices
# Word not in the vocab: scoop
# Word not in the vocab: redistributing
# Word not in the vocab: influencing
# Word not in the vocab: Nomenklatura
# Word not in the vocab: 1983-85
# Word not in the vocab: markkaa
# Word not in the vocab: markkaa
# Word not in the vocab: markkaa
# Word not in the vocab: Nichol
# Word not in the vocab: Nichol
# Word not in the vocab: Karns
# Word not in the vocab: Nichol
# Word not in the vocab: Karns
# Word not in the vocab: sputtered
# Word not in the vocab: 84.9
# Word not in the vocab: 422.5
# Word not in the vocab: 6.44
# Word not in the vocab: phase-out
# Word not in the vocab: Hostess
# Word not in the vocab: 387.8
# Word not in the vocab: cadmium
# Word not in the vocab: 80.50
# Word not in the vocab: Eveready
# Word not in the vocab: Baking
# Word not in the vocab: 55.1
# Word not in the vocab: cash-and-stock
# Word not in the vocab: Ravenswood
# Word not in the vocab: corn-buying
# Word not in the vocab: bottlenecks
# Word not in the vocab: barge
# Word not in the vocab: reaping
# Word not in the vocab: gyrate
# Word not in the vocab: scrounge
# Word not in the vocab: tows
# Word not in the vocab: Dunton
# Word not in the vocab: Barge
# Word not in the vocab: barge
# Word not in the vocab: Lyle
# Word not in the vocab: Waterloo
# Word not in the vocab: Biedermann
# Word not in the vocab: barge
# Word not in the vocab: Allendale
# Word not in the vocab: sidestep
# Word not in the vocab: larger-than-normal
# Word not in the vocab: 19.94
# Word not in the vocab: 58.64
# Word not in the vocab: 377.60
# Word not in the vocab: 494.50
# Word not in the vocab: 5.2180
# Word not in the vocab: 170,262
# Word not in the vocab: 226,570,380
# Word not in the vocab: Disputada
# Word not in the vocab: precedes
# Word not in the vocab: NetWare
# Word not in the vocab: 34.625
# Word not in the vocab: TXO
# Word not in the vocab: 721
# Word not in the vocab: constitutional-law
# Word not in the vocab: Kurland
# Word not in the vocab: McFarlan
# Word not in the vocab: DiLoreto
# Word not in the vocab: contradict
# Word not in the vocab: Delmont
# Word not in the vocab: Kurland
# Word not in the vocab: authorizes
# CPU times: user 22.9 s, sys: 1.29 s, total: 24.2 s
# Wall time: 17.1 s

# %%
def export_preds(preds, filename):
    with open(filename, "w") as out_file:
        out_file.write("\n".join(preds))

# %%
export_preds(preds, "test_output.txt")

# !python3 ../data/eval.py test_output.txt ../data/sents.answer
# Out:
# Accuracy= 0.01200848151491613
